# %%
import numpy as np
import pandas as pd
from astropy.io import fits
import matplotlib.pyplot as plt
import math 

filename = r"Y:\2D\20260423\iLocater_lab_20260423_0016_hxrgproc.fits"
data = fits.getdata(filename)
hist_data = data.flatten()

plt.figure()
plt.hist(hist_data, bins = 1000, range=(-8, -2.5), color="darkslategrey",)
plt.xlabel("Pixel Readout")
plt.ylabel("Counts")
plt.show()
